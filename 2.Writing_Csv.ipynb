# %%
import pandas as pd
df1=pd.read_csv("D:\\Data_Analysis_04-06PM\\Fortune_10.csv")
df1
# Out:
#    ID Date             Name           Companies  Inception         Revenue  \
# 0   1  Yes          Lamtone         IT Services       2009     $11,757,018
# 1   2   No        Stripfind  Financial Services       2010     $22,757,028
# 2   3   No  Canecorporation              Health       2012     $33,757,038
# 3   4  Yes         Mattouch         IT Services       2013     $44,757,048
# 4   5  Yes        Techdrill              Health       2009     $55,757,058
# 5   6   No         Techline              Health       2006     $66,757,068
# 6   7   No          Cityace              Health       2010     $77,757,078
# 7   8  Yes   Kayelectronics              Health       2009     $88,757,088
# 8   9  Yes          Ganzlax         IT Services       2011     $99,757,098
# 9  10  Yes      Trantraxlax  Government Service       2011  $1010,757,0108
#
#             Expences    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1  6,482,465 Dollars  11412916    20%
# ...

# %%
# how to use head() function in pandas

df1.head()
# Out:
#    ID Date             Name           Companies  Inception      Revenue  \
# 0   1  Yes          Lamtone         IT Services       2009  $11,757,018
# 1   2   No        Stripfind  Financial Services       2010  $22,757,028
# 2   3   No  Canecorporation              Health       2012  $33,757,038
# 3   4  Yes         Mattouch         IT Services       2013  $44,757,048
# 4   5  Yes        Techdrill              Health       2009  $55,757,058
#
#             Expences    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1  6,482,465 Dollars  11412916    20%
# 2  6,482,465 Dollars   3005820     7%
# 3  6,482,465 Dollars    652482    26%
# 4  6,482,465 Dollars   6516491     8%

# %%
df1.tail()
# Out:
#    ID Date            Name           Companies  Inception         Revenue  \
# 5   6   No        Techline              Health       2006     $66,757,068
# 6   7   No         Cityace              Health       2010     $77,757,078
# 7   8  Yes  Kayelectronics              Health       2009     $88,757,088
# 8   9  Yes         Ganzlax         IT Services       2011     $99,757,098
# 9  10  Yes     Trantraxlax  Government Service       2011  $1010,757,0108
#
#             Expences    Profit Growth
# 5  6,482,465 Dollars  16498433    23%
# 6  6,482,465 Dollars  65449161     6%
# 7  6,482,465 Dollars   1616496     4%
# 8  6,482,465 Dollars     13164    18%
# 9  6,482,465 Dollars    164684     7%

# %%
df1.head(8)
# Out:
#    ID Date             Name           Companies  Inception      Revenue  \
# 0   1  Yes          Lamtone         IT Services       2009  $11,757,018
# 1   2   No        Stripfind  Financial Services       2010  $22,757,028
# 2   3   No  Canecorporation              Health       2012  $33,757,038
# 3   4  Yes         Mattouch         IT Services       2013  $44,757,048
# 4   5  Yes        Techdrill              Health       2009  $55,757,058
# 5   6   No         Techline              Health       2006  $66,757,068
# 6   7   No          Cityace              Health       2010  $77,757,078
# 7   8  Yes   Kayelectronics              Health       2009  $88,757,088
#
#             Expences    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1  6,482,465 Dollars  11412916    20%
# 2  6,482,465 Dollars   3005820     7%
# 3  6,482,465 Dollars    652482    26%
# 4  6,482,465 Dollars   6516491     8%
# 5  6,482,465 Dollars  16498433    23%
# 6  6,482,465 Dollars  65449161     6%
# ...

# %%
df1.tail(2)
# Out:
#    ID Date         Name           Companies  Inception         Revenue  \
# 8   9  Yes      Ganzlax         IT Services       2011     $99,757,098
# 9  10  Yes  Trantraxlax  Government Service       2011  $1010,757,0108
#
#             Expences  Profit Growth
# 8  6,482,465 Dollars   13164    18%
# 9  6,482,465 Dollars  164684     7%

# %%
# How to change dtype of any columns.

df1=pd.read_csv("D:\\Data_Analysis_04-06PM\\Fortune_10.csv",dtype={"ID":"float64"})
df1
# Out:
#      ID Date             Name           Companies  Inception         Revenue  \
# 0   1.0  Yes          Lamtone         IT Services       2009     $11,757,018
# 1   2.0   No        Stripfind  Financial Services       2010     $22,757,028
# 2   3.0   No  Canecorporation              Health       2012     $33,757,038
# 3   4.0  Yes         Mattouch         IT Services       2013     $44,757,048
# 4   5.0  Yes        Techdrill              Health       2009     $55,757,058
# 5   6.0   No         Techline              Health       2006     $66,757,068
# 6   7.0   No          Cityace              Health       2010     $77,757,078
# 7   8.0  Yes   Kayelectronics              Health       2009     $88,757,088
# 8   9.0  Yes          Ganzlax         IT Services       2011     $99,757,098
# 9  10.0  Yes      Trantraxlax  Government Service       2011  $1010,757,0108
#
#             Expences    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1  6,482,465 Dollars  11412916    20%
# ...

# %%
df1=pd.read_csv("D:\\Data_Analysis_04-06PM\\Fortune_10.csv",dtype={"Inception":"float64"})
df1
# Out:
#    ID Date             Name           Companies  Inception         Revenue  \
# 0   1  Yes          Lamtone         IT Services     2009.0     $11,757,018
# 1   2   No        Stripfind  Financial Services     2010.0     $22,757,028
# 2   3   No  Canecorporation              Health     2012.0     $33,757,038
# 3   4  Yes         Mattouch         IT Services     2013.0     $44,757,048
# 4   5  Yes        Techdrill              Health     2009.0     $55,757,058
# 5   6   No         Techline              Health     2006.0     $66,757,068
# 6   7   No          Cityace              Health     2010.0     $77,757,078
# 7   8  Yes   Kayelectronics              Health     2009.0     $88,757,088
# 8   9  Yes          Ganzlax         IT Services     2011.0     $99,757,098
# 9  10  Yes      Trantraxlax  Government Service     2011.0  $1010,757,0108
#
#             Expences    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1  6,482,465 Dollars  11412916    20%
# ...

# %%
df1=pd.read_csv("D:\\Data_Analysis_04-06PM\\Fortune_10.csv",dtype={"Profit":"float64"})
df1
# Out:
#    ID Date             Name           Companies  Inception         Revenue  \
# 0   1  Yes          Lamtone         IT Services       2009     $11,757,018
# 1   2   No        Stripfind  Financial Services       2010     $22,757,028
# 2   3   No  Canecorporation              Health       2012     $33,757,038
# 3   4  Yes         Mattouch         IT Services       2013     $44,757,048
# 4   5  Yes        Techdrill              Health       2009     $55,757,058
# 5   6   No         Techline              Health       2006     $66,757,068
# 6   7   No          Cityace              Health       2010     $77,757,078
# 7   8  Yes   Kayelectronics              Health       2009     $88,757,088
# 8   9  Yes          Ganzlax         IT Services       2011     $99,757,098
# 9  10  Yes      Trantraxlax  Government Service       2011  $1010,757,0108
#
#             Expences      Profit Growth
# 0  6,482,465 Dollars   5274553.0    30%
# 1  6,482,465 Dollars  11412916.0    20%
# ...

# %%
import pandas as pd
df5=pd.read_csv("C:\\Users\\Admin\\Downloads\\Final_Employees_Data.csv")
df5
# Out:
#       Eid                Ename  Experience  Total_projects    Rating  \
# 0       1            Dana Bond           2               2  1.000000
# 1       2        Jesus Hampton           9              13  1.444444
# 2       3         Teresa Munoz          15              16  1.066667
# 3       4     Annette Dipietro          18              19  1.055556
# 4       5     Jennifer Fortner          22              15  0.681818
# ..    ...                  ...         ...             ...       ...
# 995   996         Nicole Meeks          24              27  1.125000
# 996   997         Trista Cheek           3               6  2.000000
# 997   998     Constance Rozier          14               5  0.357143
# 998   999  Elizabeth Bannister          11               9  0.818182
# 999  1000          Susan Weber          11              13  1.181818
#
#     Area_of_Interest_1 Area_of_Interest_2 Area_of_Interest_3 Language1  \
# ...

# %%
# how to change any column data if there is any other values and convert as True.
df5
# Out:
#       Eid                Ename  Experience  Total_projects    Rating  \
# 0       1            Dana Bond           2               2  1.000000
# 1       2        Jesus Hampton           9              13  1.444444
# 2       3         Teresa Munoz          15              16  1.066667
# 3       4     Annette Dipietro          18              19  1.055556
# 4       5     Jennifer Fortner          22              15  0.681818
# ..    ...                  ...         ...             ...       ...
# 995   996         Nicole Meeks          24              27  1.125000
# 996   997         Trista Cheek           3               6  2.000000
# 997   998     Constance Rozier          14               5  0.357143
# 998   999  Elizabeth Bannister          11               9  0.818182
# 999  1000          Susan Weber          11              13  1.181818
#
#     Area_of_Interest_1 Area_of_Interest_2 Area_of_Interest_3 Language1  \
# ...

# %%
df7=pd.read_csv("C:\\Users\\Admin\\Downloads\\Final_Employees_Data.csv")
df7
# Out:
#       Eid                Ename  Experience  Total_projects    Rating  \
# 0       1            Dana Bond           2               2  1.000000
# 1       2        Jesus Hampton           9              13  1.444444
# 2       3         Teresa Munoz          15              16  1.066667
# 3       4     Annette Dipietro          18              19  1.055556
# 4       5     Jennifer Fortner          22              15  0.681818
# ..    ...                  ...         ...             ...       ...
# 995   996         Nicole Meeks          24              27  1.125000
# 996   997         Trista Cheek           3               6  2.000000
# 997   998     Constance Rozier          14               5  0.357143
# 998   999  Elizabeth Bannister          11               9  0.818182
# 999  1000          Susan Weber          11              13  1.181818
#
#     Area_of_Interest_1 Area_of_Interest_2 Area_of_Interest_3 Language1  \
# ...

# %%
df1=pd.read_csv("D:\\Data_Analysis_04-06PM\\Fortune_10.csv",false_values=['True'])
df1
# Out:
#    ID Date             Name           Companies  Inception         Revenue  \
# 0   1  Yes          Lamtone         IT Services       2009     $11,757,018
# 1   2   No        Stripfind  Financial Services       2010     $22,757,028
# 2   3   No  Canecorporation              Health       2012     $33,757,038
# 3   4  Yes         Mattouch         IT Services       2013     $44,757,048
# 4   5  Yes        Techdrill              Health       2009     $55,757,058
# 5   6   No         Techline              Health       2006     $66,757,068
# 6   7   No          Cityace              Health       2010     $77,757,078
# 7   8  Yes   Kayelectronics              Health       2009     $88,757,088
# 8   9  Yes          Ganzlax         IT Services       2011     $99,757,098
# 9  10  Yes      Trantraxlax  Government Service       2011  $1010,757,0108
#
#             Expences    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1  6,482,465 Dollars  11412916    20%
# ...

# %%
df5
# Out:
#       Eid                Ename  Experience  Total_projects    Rating  \
# 0       1            Dana Bond           2               2  1.000000
# 1       2        Jesus Hampton           9              13  1.444444
# 2       3         Teresa Munoz          15              16  1.066667
# 3       4     Annette Dipietro          18              19  1.055556
# 4       5     Jennifer Fortner          22              15  0.681818
# ..    ...                  ...         ...             ...       ...
# 995   996         Nicole Meeks          24              27  1.125000
# 996   997         Trista Cheek           3               6  2.000000
# 997   998     Constance Rozier          14               5  0.357143
# 998   999  Elizabeth Bannister          11               9  0.818182
# 999  1000          Susan Weber          11              13  1.181818
#
#     Area_of_Interest_1 Area_of_Interest_2 Area_of_Interest_3 Language1  \
# ...

# %%
df7=pd.read_csv("C:\\Users\\Admin\\Downloads\\Final_Employees_Data.csv",na_values="not available")
df7
# Out:
#       Eid                Ename  Experience  Total_projects    Rating  \
# 0       1            Dana Bond           2               2  1.000000
# 1       2        Jesus Hampton           9              13  1.444444
# 2       3         Teresa Munoz          15              16  1.066667
# 3       4     Annette Dipietro          18              19  1.055556
# 4       5     Jennifer Fortner          22              15  0.681818
# ..    ...                  ...         ...             ...       ...
# 995   996         Nicole Meeks          24              27  1.125000
# 996   997         Trista Cheek           3               6  2.000000
# 997   998     Constance Rozier          14               5  0.357143
# 998   999  Elizabeth Bannister          11               9  0.818182
# 999  1000          Susan Weber          11              13  1.181818
#
#     Area_of_Interest_1 Area_of_Interest_2 Area_of_Interest_3 Language1  \
# ...

# %%
df1=pd.read_csv("D:\\Data_Analysis_04-06PM\\Fortune_10.csv",na_values="not available")
df1
# Out:
#    ID Date             Name           Companies  Inception         Revenue  \
# 0   1  NaN          Lamtone         IT Services       2009     $11,757,018
# 1   2  NaN        Stripfind  Financial Services       2010     $22,757,028
# 2   3   No  Canecorporation              Health       2012     $33,757,038
# 3   4  Yes         Mattouch         IT Services       2013     $44,757,048
# 4   5  Yes        Techdrill              Health       2009     $55,757,058
# 5   6  NaN         Techline              Health       2006     $66,757,068
# 6   7  NaN          Cityace              Health       2010     $77,757,078
# 7   8  Yes   Kayelectronics              Health       2009     $88,757,088
# 8   9  Yes          Ganzlax         IT Services       2011     $99,757,098
# 9  10  Yes      Trantraxlax  Government Service       2011  $1010,757,0108
#
#             Expences    Profit Growth
# 0  6,482,465 Dollars   5274553    NaN
# 1  6,482,465 Dollars  11412916    NaN
# ...

# %%
df1
# Out:
#    ID Date             Name           Companies  Inception         Revenue  \
# 0   1  NaN          Lamtone         IT Services       2009     $11,757,018
# 1   2  NaN        Stripfind  Financial Services       2010     $22,757,028
# 2   3   No  Canecorporation              Health       2012     $33,757,038
# 3   4  Yes         Mattouch         IT Services       2013     $44,757,048
# 4   5  Yes        Techdrill              Health       2009     $55,757,058
# 5   6  NaN         Techline              Health       2006     $66,757,068
# 6   7  NaN          Cityace              Health       2010     $77,757,078
# 7   8  Yes   Kayelectronics              Health       2009     $88,757,088
# 8   9  Yes          Ganzlax         IT Services       2011     $99,757,098
# 9  10  Yes      Trantraxlax  Government Service       2011  $1010,757,0108
#
#             Expences    Profit Growth
# 0  6,482,465 Dollars   5274553    NaN
# 1  6,482,465 Dollars  11412916    NaN
# ...

# %%
df1=pd.read_csv("D:\\Data_Analysis_04-06PM\\Fortune_10.csv",na_values={'Date':10})
df1
# Out:
#    ID Date             Name           Companies  Inception         Revenue  \
# 0   1  NaN          Lamtone         IT Services       2009     $11,757,018
# 1   2  NaN        Stripfind  Financial Services       2010     $22,757,028
# 2   3   No  Canecorporation              Health       2012     $33,757,038
# 3   4  Yes         Mattouch         IT Services       2013     $44,757,048
# 4   5  Yes        Techdrill              Health       2009     $55,757,058
# 5   6  NaN         Techline              Health       2006     $66,757,068
# 6   7  NaN          Cityace              Health       2010     $77,757,078
# 7   8  Yes   Kayelectronics              Health       2009     $88,757,088
# 8   9  Yes          Ganzlax         IT Services       2011     $99,757,098
# 9  10  Yes      Trantraxlax  Government Service       2011  $1010,757,0108
#
#             Expences    Profit Growth
# 0  6,482,465 Dollars   5274553    NaN
# 1  6,482,465 Dollars  11412916    NaN
# ...

# %%
df1=pd.read_csv("D:\\Data_Analysis_04-06PM\\Fortune_10.csv", na_values=True)

# %%
df1
# Out:
#      ID Date             Name           Companies  Inception         Revenue  \
# 0   NaN    0                0         IT Services       2009     $11,757,018
# 1   2.0    0                0  Financial Services       2010     $22,757,028
# 2   3.0   No  Canecorporation              Health       2012     $33,757,038
# 3   4.0  Yes         Mattouch         IT Services       2013     $44,757,048
# 4   5.0  Yes        Techdrill              Health       2009     $55,757,058
# 5   6.0  NaN         Techline              Health       2006     $66,757,068
# 6   7.0  NaN          Cityace              Health       2010     $77,757,078
# 7   8.0  Yes   Kayelectronics              Health       2009     $88,757,088
# 8   9.0  Yes          Ganzlax         IT Services       2011     $99,757,098
# 9  10.0  Yes      Trantraxlax  Government Service       2011  $1010,757,0108
#
#             Expences    Profit Growth
# 0  6,482,465 Dollars   5274553     0%
# 1  6,482,465 Dollars  11412916     0%
# ...

# %%
df2=pd.read_csv("D:\\Data_Analysis_04-06PM\\Fortune_10.csv", na_values=False)
df2
# Out:
#    ID Date             Name           Companies  Inception         Revenue  \
# 0   1  NaN              NaN         IT Services       2009     $11,757,018
# 1   2  NaN              NaN  Financial Services       2010     $22,757,028
# 2   3   No  Canecorporation              Health       2012     $33,757,038
# 3   4  Yes         Mattouch         IT Services       2013     $44,757,048
# 4   5  Yes        Techdrill              Health       2009     $55,757,058
# 5   6  NaN         Techline              Health       2006     $66,757,068
# 6   7  NaN          Cityace              Health       2010     $77,757,078
# 7   8  Yes   Kayelectronics              Health       2009     $88,757,088
# 8   9  Yes          Ganzlax         IT Services       2011     $99,757,098
# 9  10  Yes      Trantraxlax  Government Service       2011  $1010,757,0108
#
#             Expences    Profit Growth
# 0  6,482,465 Dollars   5274553     0%
# 1  6,482,465 Dollars  11412916     0%
# ...

# %%
df3=pd.read_csv("D:\\Data_Analysis_04-06PM\\Fortune_10.csv", keep_default_na=True)
df3
# Out:
#    ID Date             Name           Companies  Inception         Revenue  \
# 0   1    0                0         IT Services       2009     $11,757,018
# 1   2    0                0  Financial Services       2010     $22,757,028
# 2   3   No  Canecorporation              Health       2012     $33,757,038
# 3   4  Yes         Mattouch         IT Services       2013     $44,757,048
# 4   5  Yes        Techdrill              Health       2009     $55,757,058
# 5   6  NaN         Techline              Health       2006     $66,757,068
# 6   7  NaN          Cityace              Health       2010     $77,757,078
# 7   8  Yes   Kayelectronics              Health       2009     $88,757,088
# 8   9  Yes          Ganzlax         IT Services       2011     $99,757,098
# 9  10  Yes      Trantraxlax  Government Service       2011  $1010,757,0108
#
#             Expences    Profit Growth
# 0  6,482,465 Dollars   5274553     0%
# 1  6,482,465 Dollars  11412916     0%
# ...

# %%
# How to find missing value in interpreter
df2=pd.read_csv("D:\\Data_Analysis_04-06PM\\Fortune_10.csv", na_filter=False)
df2
# Out:
#    ID Date             Name           Companies  Inception         Revenue  \
# 0   1  nan                0         IT Services       2009     $11,757,018
# 1   2  nan                0  Financial Services       2010     $22,757,028
# 2   3   No  Canecorporation              Health       2012     $33,757,038
# 3   4  Yes         Mattouch         IT Services       2013     $44,757,048
# 4   5  Yes        Techdrill              Health       2009     $55,757,058
# 5   6  nan         Techline              Health       2006     $66,757,068
# 6   7  nan          Cityace              Health       2010     $77,757,078
# 7   8  Yes   Kayelectronics              Health       2009     $88,757,088
# 8   9  Yes          Ganzlax         IT Services       2011     $99,757,098
# 9  10  Yes      Trantraxlax  Government Service       2011  $1010,757,0108
#
#             Expences    Profit Growth
# 0  6,482,465 Dollars   5274553    nan
# 1  6,482,465 Dollars  11412916    nan
# ...

# %%
df2=pd.read_csv("D:\\Data_Analysis_04-06PM\\Fortune_10.csv", na_filter=True)
df2
# Out:
#    ID Date             Name           Companies  Inception         Revenue  \
# 0   1  NaN                0         IT Services       2009     $11,757,018
# 1   2  NaN                0  Financial Services       2010     $22,757,028
# 2   3   No  Canecorporation              Health       2012     $33,757,038
# 3   4  Yes         Mattouch         IT Services       2013     $44,757,048
# 4   5  Yes        Techdrill              Health       2009     $55,757,058
# 5   6  NaN         Techline              Health       2006     $66,757,068
# 6   7  NaN          Cityace              Health       2010     $77,757,078
# 7   8  Yes   Kayelectronics              Health       2009     $88,757,088
# 8   9  Yes          Ganzlax         IT Services       2011     $99,757,098
# 9  10  Yes      Trantraxlax  Government Service       2011  $1010,757,0108
#
#             Expences    Profit Growth
# 0  6,482,465 Dollars   5274553    NaN
# 1  6,482,465 Dollars  11412916    NaN
# ...

# %%
df2
# Out:
#    ID Date             Name           Companies  Inception         Revenue  \
# 0   1  NaN                0         IT Services       2009     $11,757,018
# 1   2  NaN                0  Financial Services       2010     $22,757,028
# 2   3   No  Canecorporation              Health       2012     $33,757,038
# 3   4  Yes         Mattouch         IT Services       2013     $44,757,048
# 4   5  Yes        Techdrill              Health       2009     $55,757,058
# 5   6  NaN         Techline              Health       2006     $66,757,068
# 6   7  NaN          Cityace              Health       2010     $77,757,078
# 7   8  Yes   Kayelectronics              Health       2009     $88,757,088
# 8   9  Yes          Ganzlax         IT Services       2011     $99,757,098
# 9  10  Yes      Trantraxlax  Government Service       2011  $1010,757,0108
#
#             Expences    Profit Growth
# 0  6,482,465 Dollars   5274553    NaN
# 1  6,482,465 Dollars  11412916    NaN
# ...
